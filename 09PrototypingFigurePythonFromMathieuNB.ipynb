# %%
import numpy as np
import xarray as xr
import pandas as pd

import matplotlib.pyplot as plt
import cmocean as cmo

import argo_processing as ap

import warnings
warnings.filterwarnings('ignore')

data_path = "/data/GLOBARGO/float_data/"

# %%
filename ='SD5904677_027.nc'
prof = xr.open_dataset(data_path+filename)
prof = ap.format_profil(prof)

ap.profile_plot(prof, z_max = 1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 filename ='SD5904677_027.nc'
#       2 prof = xr.open_dataset(data_path+filename)
# ----> 3 prof = ap.format_profil(prof)
#       5 ap.profile_plot(prof, z_max = 1000)
#
# File /data/GLOBARGO/src/argo_processing.py:88, in format_profil(Profil_test, with_bbp, n_prof)
#      85 O2sol_a = gsw.O2sol(SA = SA_a, CT = CT_a, p = pres_a, lon= lon, lat = lat) # umol/kg
#      87 N2_a, p_mid = gsw.stability.Nsquared(SA_a, CT_a, pres_a, lat=lat)
# ---> 88 depth_mid = -gsw.z_from_p(p_mid, lat)
#      90 ds = xr.Dataset(
#      91     data_vars=dict(
#      92         time = time,
#    (...)
#     106                 'depth_mid': (['depth_mid'], depth_mid.data)
#     107                })
#     109 var_list = ['CHLA_ADJUSTED','BBP700_ADJUSTED','BBP532_ADJUSTED',
# ...
